# %% [markdown]
# # Operators in Python

# %% [markdown]
# ## Arithmetic Operators

# %% [markdown]
# ### Addition operator

# %%
# Used to add two or more items together

# %%
6 + 4
# Out:
# 10

# %%
5 + 3
# Out:
# 8

# %%
10 + 2
# Out:
# 12

# %%
8 + 4
# Out:
# 12

# %%
3 + 7
# Out:
# 10

# %%
2 + 5
# Out:
# 7

# %%
7 + 7
# Out:
# 14

# %%
8 + 9
# Out:
# 17

# %%
1 + 17
# Out:
# 18

# %%
3.3 + 4.9
# Out:
# 8.2

# %% [markdown]
# ### Subtraction operator

# %%
# Used to find the difference between two or more items

# %%
10 - 2
# Out:
# 8

# %%
4 - 3
# Out:
# 1

# %%
2 - 5
# Out:
# -3

# %%
3.5 - 5.6
# Out:
# -2.0999999999999996

# %%
20 -100
# Out:
# -80

# %%
10 - 5
# Out:
# 5

# %%
7 - 4
# Out:
# 3

# %%
5 - 1
# Out:
# 4

# %%
4 - 0
# Out:
# 4

# %%
0 - 4
# Out:
# -4

# %% [markdown]
# ### Multiplication operator

# %%
# Used to multiply or find the product of two or more items

# %%
4 * 5
# Out:
# 20

# %%
5 * 8
# Out:
# 40

# %%
2.5 * 3.7
# Out:
# 9.25

# %%
4 * 10
# Out:
# 40

# %%
-10 * 2.2
# Out:
# -22.0

# %%
6 * 5
# Out:
# 30

# %%
7 * 11
# Out:
# 77

# %%
-5 * -5.5
# Out:
# 27.5

# %%
10 * 10
# Out:
# 100

# %%
3 * 3
# Out:
# 9

# %% [markdown]
# ### Division operator

# %%
# Used to divide two or more items

# %%
10/2
# Out:
# 5.0

# %%
4/4
# Out:
# 1.0

# %%
2/5
# Out:
# 0.4

# %%
4/3
# Out:
# 1.3333333333333333

# %%
-12/6
# Out:
# -2.0

# %%
-6/-12
# Out:
# 0.5

# %%
-5/7
# Out:
# -0.7142857142857143

# %%
-9/6
# Out:
# -1.5

# %%
5/5
# Out:
# 1.0

# %%
50/2
# Out:
# 25.0

# %% [markdown]
# ### Exponential operator

# %%
# Also known as 'Power of' operator, it is used to find the power of numbers

# %%
2 ** 3
# Out:
# 8

# %%
1.5 ** 2
# Out:
# 2.25

# %%
(-2) ** 3
# Out:
# -8

# %%
(3 + 2) ** 2
# Out:
# 25

# %%
(1 + 2j) ** 2
# Out:
# (-3+4j)

# %%
2 ** -3
# Out:
# 0.125

# %%
3 ** 3
# Out:
# 27

# %%
10 ** 10
# Out:
# 10000000000

# %%
100 ** 2
# Out:
# 10000

# %%
5 ** 5
# Out:
# 3125

# %% [markdown]
# ### Floor division

# %%
#It is used to divide numbers and return the integer part of the answer

# %%
10 // 3
# Out:
# 3

# %%
(-15) // 4
# Out:
# -4

# %%
8.5 // 2.5
# Out:
# 3.0

# %%
1 // 3
# Out:
# 0

# %%
(5 + 3) // 2
# Out:
# 4

# %%
17 // 4
# Out:
# 4

# %%
0 // 5
# Out:
# 0

# %%
1000 // 42
# Out:
# 23

# %%
15 // 4.0
# Out:
# 3.0

# %%
10 // 2.5
# Out:
# 4.0

# %% [markdown]
# ### Modulus operator

# %%
#It is used to divide numbers and return the remainder part of the answer

# %%
10 % 3
# Out:
# 1

# %%
(-15) % 4
# Out:
# 1

# %%
8.5 % 2.5
# Out:
# 1.0

# %%
1 % 3
# Out:
# 1

# %%
(5 + 3) % 2
# Out:
# 0

# %%
1000 % 42
# Out:
# 34

# %%
0 % 5
# Out:
# 0

# %%
15 % 4.0
# Out:
# 3.0

# %%
(-17) % 5
# Out:
# 3

# %%
3 % 2
# Out:
# 1

# %% [markdown]
# ## Logical Operators

# %% [markdown]
# ### OR

# %%
#for combining conditions, evaluating truthiness,it returns true if at least one of the conditions is true, otherwise it returns false

# %%
(5 > 3) or (10 < 8)
# Out:
# True

# %%
(5 == 5) or ('h' in 'world')
# Out:
# True

# %%
age = 25
(age < 18) or (age >= 65)
# Out:
# False

# %%
x = 8
(1 < x < 10) or (20 < x < 30)
# Out:
# True

# %%
fruits = {'apple', 'banana', 'orange'}
('kiwi' in fruits) or ('orange' in fruits)
# Out:
# True

# %%
idt = {'name': 'John', 'age': 25}
('gender' in idt) or ('age' in idt)
# Out:
# True

# %%
score = 28
(score < 0) or (score > 100)
# Out:
# False

# %%
x = 7
1 < x < 5 or 8 < x < 10
# Out:
# False

# %%
5 > 10 or 2 < 10
# Out:
# True

# %%
12 < 5 or 5 == 10
# Out:
# False

# %% [markdown]
# ### AND

# %%
#for combining conditions, evaluating truthiness,it returns true if all of the conditions are true, otherwise it returns false

# %%
(5 > 3) and (10 < 8)
# Out:
# False

# %%
(5 == 5) and ('he' in 'world')
# Out:
# False

# %%
age = 25
(age > 18) and (age < 65)
# Out:
# True

# %%
x = 8
(1 < x < 10) and (5 < x < 20)
# Out:
# True

# %%
fruits = {'apple', 'banana', 'orange'}
('kiwi' in fruits) and ('orange' in fruits)
# Out:
# False

# %%
idt = {'name': 'John', 'age': 25}
('gender' in idt) and ('age' in idt)
# Out:
# False

# %%
score = 28
(score < 0) and (score > 100)
# Out:
# False

# %%
x = 7
1 < x < 10 and 5 < x < 20
# Out:
# True

# %%
5 > 10 and 2 < 10
# Out:
# False

# %%
12 < 5 and 5 == 10
# Out:
# False

# %% [markdown]
# ### NOT

# %%
#It negates boolean values, conditions, and expressions.

# %%
not (5 > 3)
# Out:
# False

# %%
age = 15
not (age >= 18)
# Out:
# True

# %%
x = 15
not(1 < x < 10)
# Out:
# True

# %%
fruits = {'apple', 'banana', 'orange'}
not ('kiwi' in fruits)
# Out:
# True

# %%
idt = {'name': 'John', 'age': 25}
not ('gender' in idt)
# Out:
# True

# %%
score = 28
not (score <= 0)
# Out:
# True

# %%
x = 7
not (1 < x < 10 and 5 < x < 20)
# Out:
# False

# %%
x = 8
not (1 < x < 10) and (5 < x < 20)
# Out:
# False

# %%
status = 'pending'
not (status == 'approved')
# Out:
# True

# %%
not (3 == 3)
# Out:
# False

# %%
not (4 < 10)
# Out:
# False

# %% [markdown]
# ## Membership operator

# %% [markdown]
# ### IN

# %%
#Used to check membership in different data structures and types in Python

# %%
numbers = [1, 2, 3, 4, 5]
3 in numbers
# Out:
# True

# %%
message = "Hello, world!"
"world" in message
# Out:
# True

# %%
fruits = ('apple', 'banana', 'orange')
'kiwi' in fruits
# Out:
# False

# %%
colors = {'red', 'green', 'blue'}
'yellow' in colors
# Out:
# False

# %%
idt = {'name': 'John', 'age': 25}
'age' in idt
# Out:
# True

# %%
5 in range(1, 10)
# Out:
# True

# %%
'A' in 'ABCDE'
# Out:
# True

# %%
sentence = "Python is powerful"
"python" in sentence.lower()
# Out:
# True

# %%
'C' in 'ABCDEF'
# Out:
# True

# %%
'cat' in 'concatenate'
# Out:
# True

# %% [markdown]
# ### Not In

# %%
#Used to check absence or non-membership in different data structures and types in Python

# %%
numbers = [1, 2, 3, 4, 5]
6 not in numbers
# Out:
# True

# %%
fruits = ('apple', 'banana', 'orange')
'kiwi' not in fruits
# Out:
# True

# %%
colors = {'red', 'green', 'blue'}
'yellow' not in colors
# Out:
# True

# %%
idt = {'name': 'John', 'age': 25}
'gender' not in idt
# Out:
# True

# %%
5 not in range(1, 10)
# Out:
# False

# %%
'Z' not in 'ABCDE'
# Out:
# True

# %%
'cat' not in 'concatenate'
# Out:
# False

# %%
numbers = [1, 2, 3, 4, 5]
3 not in numbers
# Out:
# False

# %%
'o' not in 'XYLOPHONE'
# Out:
# True

# %%
'A' not in 'ZDFER'
# Out:
# True

# %% [markdown]
# ## Comparison operator

# %% [markdown]
# ### Less than <

# %%
#Compares different data types and structures in Python

# %%
5 < 10
# Out:
# True

# %%
a = 15
b = 20
a < b
# Out:
# True

# %%
3.14 < 4.56
# Out:
# True

# %%
-5 < 0
# Out:
# True

# %%
numbers = [1, 2, 3, 4, 5]
3 < numbers[2]
# Out:
# False

# %%
10 < 15
# Out:
# True

# %%
'b' < 'a'
# Out:
# False

# %%
'a' < 'b'
# Out:
# True

# %%
2.5 < 3
# Out:
# True

# %%
5 < -4
# Out:
# False

# %% [markdown]
# ### Greater than

# %%
#Compares different data types and structures in Python

# %%
15 > 10
# Out:
# True

# %%
a = 25
b = 20
a > b
# Out:
# True

# %%
'banana' > 'apple'
# Out:
# True

# %%
4.56 > 3.14
# Out:
# True

# %%
5 > -3
# Out:
# True

# %%
numbers = [1, 2, 3, 4, 5]
3 > numbers[4]
# Out:
# False

# %%
'xyz' > 'abc'
# Out:
# True

# %%
False > True
# Out:
# False

# %%
'b' > 'a'
# Out:
# True

# %%
3.5 > 3
# Out:
# True

# %% [markdown]
# ### Greater than or equal to (>=)

# %%
#Compares different data types and structures in Python

# %%
15 >= 10
# Out:
# True

# %%
a = 25
b = 20
a >= b
# Out:
# True

# %%
'banana' >= 'apple'
# Out:
# True

# %%
4.56 >= 3.14
# Out:
# True

# %%
5 >= -3
# Out:
# True

# %%
numbers = [1, 2, 3, 4, 5]
3 >= numbers[4]
# Out:
# False

# %%
'xyz' >= 'abc'
# Out:
# True

# %%
'b' >= 'a'
# Out:
# True

# %%
3.5 >= 3
# Out:
# True

# %%
10 >= 15
# Out:
# False

# %% [markdown]
# ### Less than or equal to (>=)

# %%
#Compares different data types and structures in Python

# %%
15 <= 10
# Out:
# False

# %%
10 <= 15
# Out:
# True

# %%
3.5 <= 3
# Out:
# False

# %%
'b' <= 'a'
# Out:
# False

# %%
'xyz' <= 'abc'
# Out:
# False

# %%
numbers = [1, 2, 3, 4, 5]
3 <= numbers[4]
# Out:
# True

# %%
5 <= -3
# Out:
# False

# %%
4.56 <= 3.14
# Out:
# False

# %%
'banana' <= 'apple'
# Out:
# False

# %%
a = 25
b = 20
a <= b
# Out:
# False

# %% [markdown]
# ### Equality Operator

# %%
#Compares different data types and structures in Python

# %%
10 == 10
# Out:
# True

# %%
a = 15
b = 15
a == b
# Out:
# True

# %%
'apple' == 'apple'
# Out:
# True

# %%
3.14 == 3.14
# Out:
# True

# %%
5 == 5.0
# Out:
# True

# %%
-5 == -5
# Out:
# True

# %%
True == True
# Out:
# True

# %%
'5' == 5
# Out:
# False

# %%
set_a = {1, 2, 3}
set_b = {3, 2, 1}
set_a == set_b
# Out:
# True

# %%
'a' == 'a'
# Out:
# True

# %% [markdown]
# ### Not equal to or Inequality Operator

# %%
#Compares different data types and structures in Python

# %%
10 != 5
# Out:
# True

# %%
a = 15
b = 20
a != b
# Out:
# True

# %%
'apple' != 'orange'
# Out:
# True

# %%
3.14 != 2.71
# Out:
# True

# %%
5 != 5.0
# Out:
# False

# %%
-5 != 5
# Out:
# True

# %%
True != False
# Out:
# True

# %%
numbers_a = [1, 2, 3]
numbers_b = [4, 5, 6]
numbers_a != numbers_b
# Out:
# True

# %%
'5' != 5
# Out:
# True

# %%
'a' != 'b'
# Out:
# True

# %% [markdown]
# ### Assignment operator

# %%
#Used to values to variables

# %%
x = 10

# %%
message = "Hello, World!"

# %%
sum_result = 5 + 7

# %%
is_true = True

# %%
numbers = [1, 2, 3, 4, 5]

# %%
person = {'name': 'Alice', 'age': 25}

# %%
a = b = c = 10

# %%
x = 10
y = x

# %%
a, b, c = 1, 2, 3

# %%
[num1, num2, num3] = [10, 20, 30]

# %% [markdown]
# Sage : Clean and well formatted. Weldone
